# %%
import kfp
from kfp import dsl
from kfp.components import create_component_from_func

def create_experiment(experiment_name, run_name, run_metrics, model, confusion_matrix_path=None, roc_auc_plot_path=None, run_params=None):
    import mlflow
    mlflow.set_experiment(experiment_name)

    with mlflow.start_run():
        if run_params is not None:
            for param in run_params:
                mlflow.log_param(param, run_params[param])

        for metric in run_metrics:
            mlflow.log_metric(metric, run_metrics[metric])

        mlflow.sklearn.log_model(model, "model")

        if confusion_matrix_path is not None:
            mlflow.log_artifact(confusion_matrix_path, 'confusion_matrix')

        if roc_auc_plot_path is not None:
            mlflow.log_artifact(roc_auc_plot_path, 'roc_auc_plot')

        mlflow.set_tag("tag1", "Random Forest")
        mlflow.set_tags({"tag2": "Randomized Search CV", "tag3": "Production"})

    print('Run - %s is logged to Experiment - %s' % (run_name, experiment_name))

# Define a lightweight Python component for creating the experiment
create_experiment_op = create_component_from_func(
    create_experiment,
    base_image='python:3.9',
    packages_to_install=['mlflow==1.21.0']
)

@dsl.pipeline(
    name='ML Experiment Pipeline',
    description='Pipeline for running multiple ML experiments and tracking with MLflow'
)
def ml_experiment_pipeline():
    experiment_name = "my_experiment"
    run_name = "my_run"
    run_metrics = {"accuracy": 0.95, "precision": 0.9, "recall": 0.8}
    model = "my_model.pkl"
    confusion_matrix_path = "confusion_matrix.png"
    roc_auc_plot_path = "roc_auc_plot.png"
    run_params = {"n_estimators": 100, "max_depth": 5}

    create_experiment(experiment_name, run_name, run_metrics, model, confusion_matrix_path, roc_auc_plot_path, run_params)


if __name__ == '__main__':
    # Compile the pipeline
    kfp.compiler.Compiler().compile(ml_experiment_pipeline, 'ml_experiment_pipeline.tar.gz')

    # Specify the Kubeflow Pipelines API endpoint
    kfp_endpoint = 'http://127.0.0.1:8080'

    # Submit the pipeline run to Kubeflow Pipelines
    kfp_client = kfp.Client(host=kfp_endpoint)
    kfp_client.create_run_from_pipeline_package('ml_experiment_pipeline.tar.gz', arguments={})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\anaconda_3\envs\mlops-task\lib\logging\__init__.py:1086, in StreamHandler.emit(self, record)
#    1085 # issue 35046: merged two stream.writes into one.
# -> 1086 stream.write(msg + self.terminator)
#    1087 self.flush()
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\mlflow\utils\logging_utils.py:25, in MlflowLoggingStream.write(self, text)
#      24 if self._enabled:
# ---> 25     sys.stderr.write(text)
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\colorama\ansitowin32.py:47, in StreamWrapper.write(self, text)
#      46 def write(self, text):
# ---> 47     self.__convertor.write(text)
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\colorama\ansitowin32.py:177, in AnsiToWin32.write(self, text)
#     176 if self.strip or self.convert:
# --> 177     self.write_and_convert(text)
#     178 else:
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\colorama\ansitowin32.py:205, in AnsiToWin32.write_and_convert(self, text)
#     204     cursor = end
# --> 205 self.write_plain_text(text, cursor, len(text))
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\colorama\ansitowin32.py:210, in AnsiToWin32.write_plain_text(self, text, start, end)
#     209 if start < end:
# --> 210     self.wrapped.write(text[start:end])
#     211     self.wrapped.flush()
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\ipykernel\iostream.py:547, in OutStream.write(self, string)
#     546 if self.pub_thread is None:
# --> 547     raise ValueError("I/O operation on closed file")
#     548 else:
#
# ValueError: I/O operation on closed file
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 55
#      50     create_experiment(experiment_name, run_name, run_metrics, model, confusion_matrix_path, roc_auc_plot_path, run_params)
#      53 if __name__ == '__main__':
#      54     # Compile the pipeline
# ---> 55     kfp.compiler.Compiler().compile(ml_experiment_pipeline, 'ml_experiment_pipeline.tar.gz')
#      57     # Specify the Kubeflow Pipelines API endpoint
#      58     kfp_endpoint = 'http://127.0.0.1:8080'
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\kfp\compiler\compiler.py:1176, in Compiler.compile(self, pipeline_func, package_path, type_check, pipeline_conf)
#    1174 try:
#    1175     kfp.TYPE_CHECK = type_check
# -> 1176     self._create_and_write_workflow(
#    1177         pipeline_func=pipeline_func,
#    1178         pipeline_conf=pipeline_conf,
#    1179         package_path=package_path)
#    1180 finally:
#    1181     kfp.TYPE_CHECK = type_check_old_value
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\kfp\compiler\compiler.py:1228, in Compiler._create_and_write_workflow(self, pipeline_func, pipeline_name, pipeline_description, params_list, pipeline_conf, package_path)
#    1219 def _create_and_write_workflow(self,
#    1220                                pipeline_func: Callable,
#    1221                                pipeline_name: Text = None,
#    (...)
#    1224                                pipeline_conf: dsl.PipelineConf = None,
#    1225                                package_path: Text = None) -> None:
#    1226     """Compile the given pipeline function and dump it to specified file
#    1227     format."""
# -> 1228     workflow = self._create_workflow(pipeline_func, pipeline_name,
#    1229                                      pipeline_description, params_list,
#    1230                                      pipeline_conf)
#    1231     self._write_workflow(workflow, package_path)
#    1232     _validate_workflow(workflow)
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\kfp\compiler\compiler.py:1006, in Compiler._create_workflow(self, pipeline_func, pipeline_name, pipeline_description, params_list, pipeline_conf)
#    1003         args_list.append(param)
#    1005 with dsl.Pipeline(pipeline_name) as dsl_pipeline:
# -> 1006     pipeline_func(*args_list, **kwargs_dict)
#    1008 pipeline_conf = pipeline_conf or dsl_pipeline.conf  # Configuration passed to the compiler is overriding. Unfortunately, it's not trivial to detect whether the dsl_pipeline.conf was ever modified.
#    1010 self._validate_exit_handler(dsl_pipeline)
#
# Cell In[1], line 50, in ml_experiment_pipeline()
#      47 roc_auc_plot_path = "roc_auc_plot.png"
#      48 run_params = {"n_estimators": 100, "max_depth": 5}
# ---> 50 create_experiment(experiment_name, run_name, run_metrics, model, confusion_matrix_path, roc_auc_plot_path, run_params)
#
# Cell In[1], line 7, in create_experiment(experiment_name, run_name, run_metrics, model, confusion_matrix_path, roc_auc_plot_path, run_params)
#       5 def create_experiment(experiment_name, run_name, run_metrics, model, confusion_matrix_path=None, roc_auc_plot_path=None, run_params=None):
#       6     import mlflow
# ----> 7     mlflow.set_experiment(experiment_name)
#       9     with mlflow.start_run():
#      10         if run_params is not None:
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\mlflow\tracking\fluent.py:128, in set_experiment(experiment_name, experiment_id)
#     126 experiment = client.get_experiment_by_name(experiment_name)
#     127 if not experiment:
# --> 128     _logger.info(
#     129         "Experiment with name '%s' does not exist. Creating a new experiment.",
#     130         experiment_name,
#     131     )
#     132     # NB: If two simultaneous threads or processes attempt to set the same experiment
#     133     # simultaneously, a race condition may be encountered here wherein experiment creation
#     134     # fails
#     135     experiment_id = client.create_experiment(experiment_name)
#
# File C:\anaconda_3\envs\mlops-task\lib\logging\__init__.py:1446, in Logger.info(self, msg, *args, **kwargs)
#    1437 """
#    1438 Log 'msg % args' with severity 'INFO'.
#    1439
#    (...)
#    1443 logger.info("Houston, we have a %s", "interesting problem", exc_info=1)
#    1444 """
#    1445 if self.isEnabledFor(INFO):
# -> 1446     self._log(INFO, msg, args, **kwargs)
#
# File C:\anaconda_3\envs\mlops-task\lib\logging\__init__.py:1589, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1586         exc_info = sys.exc_info()
#    1587 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1588                          exc_info, func, extra, sinfo)
# -> 1589 self.handle(record)
#
# File C:\anaconda_3\envs\mlops-task\lib\logging\__init__.py:1599, in Logger.handle(self, record)
#    1592 """
#    1593 Call the handlers for the specified record.
#    1594
#    1595 This method is used for unpickled records received from a socket, as
#    1596 well as those created locally. Logger-level filtering is applied.
#    1597 """
#    1598 if (not self.disabled) and self.filter(record):
# -> 1599     self.callHandlers(record)
#
# File C:\anaconda_3\envs\mlops-task\lib\logging\__init__.py:1661, in Logger.callHandlers(self, record)
#    1659     found = found + 1
#    1660     if record.levelno >= hdlr.level:
# -> 1661         hdlr.handle(record)
#    1662 if not c.propagate:
#    1663     c = None    #break out
#
# File C:\anaconda_3\envs\mlops-task\lib\logging\__init__.py:952, in Handler.handle(self, record)
#     950 self.acquire()
#     951 try:
# --> 952     self.emit(record)
#     953 finally:
#     954     self.release()
#
# File C:\anaconda_3\envs\mlops-task\lib\logging\__init__.py:1091, in StreamHandler.emit(self, record)
#    1089     raise
#    1090 except Exception:
# -> 1091     self.handleError(record)
#
# File C:\anaconda_3\envs\mlops-task\lib\logging\__init__.py:1004, in Handler.handleError(self, record)
#    1002 t, v, tb = sys.exc_info()
#    1003 try:
# -> 1004     sys.stderr.write('--- Logging error ---\n')
#    1005     traceback.print_exception(t, v, tb, None, sys.stderr)
#    1006     sys.stderr.write('Call stack:\n')
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\colorama\ansitowin32.py:47, in StreamWrapper.write(self, text)
#      46 def write(self, text):
# ---> 47     self.__convertor.write(text)
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\colorama\ansitowin32.py:177, in AnsiToWin32.write(self, text)
#     175 def write(self, text):
#     176     if self.strip or self.convert:
# --> 177         self.write_and_convert(text)
#     178     else:
#     179         self.wrapped.write(text)
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\colorama\ansitowin32.py:205, in AnsiToWin32.write_and_convert(self, text)
#     203     self.convert_ansi(*match.groups())
#     204     cursor = end
# --> 205 self.write_plain_text(text, cursor, len(text))
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\colorama\ansitowin32.py:210, in AnsiToWin32.write_plain_text(self, text, start, end)
#     208 def write_plain_text(self, text, start, end):
#     209     if start < end:
# --> 210         self.wrapped.write(text[start:end])
#     211         self.wrapped.flush()
#
# File C:\anaconda_3\envs\mlops-task\lib\site-packages\ipykernel\iostream.py:547, in OutStream.write(self, string)
#     544             print(f"Write failed: {e}", file=sys.__stderr__)
#     546 if self.pub_thread is None:
# --> 547     raise ValueError("I/O operation on closed file")
#     548 else:
#     550     is_child = not self._is_master_process()
#
# ValueError: I/O operation on closed file
